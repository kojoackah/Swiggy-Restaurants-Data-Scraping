# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.swiggy.com'
response = requests.get(url)

urls = []

soup = BeautifulSoup(response.content,"html.parser")
for a_href in soup.find_all("a",href =True):
    urls.append(a_href["href"])

# %%
# help(urls)

# %%
urls.sort
# Out:
# <function list.sort(*, key=None, reverse=False)>

# %%
del urls[-4:]

# %%
urls
# Out:
# ['/ahmedabad',
#  '/bangalore',
#  '/chennai',
#  '/delhi',
#  '/gurgaon',
#  '/hyderabad',
#  '/kolkata',
#  '/mumbai',
#  '/pune',
#  '#city-links',
#  'https://play.google.com/store/apps/details?id=in.swiggy.android',
#  'https://itunes.apple.com/in/app/swiggy-food-order-delivery/id989540920',
#  '/about',
#  '/team',
#  '/careers',
#  'https://blog.swiggy.com',
#  '/bug-bounty',
#  '/swiggy-super',
#  'https://corporate.swiggy.com',
#  '/swiggy-instamart',
#  '/support',
#  'https://partner-with-us.swiggy.com/onboard#/swiggy',
#  'https://ride.swiggy.com/',
#  '/terms-and-conditions',
#  '/refund-policy',
#  '/privacy-policy',
#  '/cookie-policy',
#  '/offer-terms',
#  '/beware-of-phishing-and-fraud',
#  '/tnc-corporate-sm',
#  '/tnc-corporate-discount',
#  'https://itunes.apple.com/in/app/id989540920?referrer=utm_source%3Dswiggy%26utm_medium%3Dhomepage',
#  'https://play.google.com/store/apps/details?id=in.swiggy.android&referrer=utm_source%3Dswiggy%26utm_medium%3Dheader',
#  '/city/abohar',
#  '/city/adilabad',
#  '/city/adityapur',
#  '/city/adoni',
#  '/city/agartala',
#  '/city/agra',
#  '/city/ahmedabad',
#  '/city/ahmednagar',
#  '/city/aizawl',
#  '/city/ajmer',
#  '/city/akola',
#  '/city/alappuzha',
#  '/city/aligarh',
#  '/city/alipurduar',
#  '/city/allahabad',
#  '/city/almora',
#  '/city/alwar',
#  '/city/amalapuram',
#  '/city/ambala',
#  '/city/ambejogai',
#  '/city/ambikapur',
#  '/city/ambur',
#  '/city/amravati',
#  '/city/amreli',
#  '/city/amritsar',
#  '/city/anand',
#  '/city/anantapur',
#  '/city/angul',
#  '/city/ankleshwar',
#  '/city/arakkonam',
#  '/city/arambagh',
#  '/city/arrah',
#  '/city/aruppukottai',
#  '/city/asansol',
#  '/city/aurangabad',
#  '/city/aurangabad_bihar',
#  '/city/azamgarh',
#  '/city/baddi',
#  '/city/bagalkot',
#  '/city/bagdogra',
#  '/city/bagula',
#  '/city/bahadurgarh',
#  '/city/bahraich',
#  '/city/balaghat',
#  '/city/balangir',
#  '/city/balasore',
#  '/city/ballari',
#  '/city/balrampur',
#  '/city/balurghat',
#  '/city/banda',
#  '/city/bangalore',
#  '/city/bankabihar',
#  '/city/bankura',
#  '/city/bantwal',
#  '/city/bapatlachirala',
#  '/city/baramati',
#  '/city/baran',
#  '/city/baraut',
#  '/city/bardhaman',
#  '/city/bardoli',
#  '/city/bareilly',
#  '/city/barh',
#  '/city/baripada',
#  '/city/barmer',
#  '/city/barnala',
#  '/city/barshi',
#  '/city/barwani',
#  '/city/basirhat',
#  '/city/basti',
#  '/city/batala',
#  '/city/bathinda',
#  '/city/beawar',
#  '/city/beed',
#  '/city/begusarai',
#  '/city/bela-pratapgarh',
#  '/city/belgaum',
#  '/city/berhampore',
#  '/city/berhampur',
#  '/city/bettiah',
#  '/city/betul',
#  '/city/bhadohi',
#  '/city/bhadrachalam',
#  '/city/bhadrak',
#  '/city/bhadravati',
#  '/city/bhagalpur',
#  '/city/bhandara',
#  '/city/bharabanki',
#  '/city/bharatpur',
#  '/city/bharuch',
#  '/city/bhatkal',
#  '/city/bhavnagar',
#  '/city/bhawanipatna',
#  '/city/bhilai',
#  '/city/bhilwara',
#  '/city/bhimavaram',
#  '/city/bhind',
#  '/city/bhiwadi',
#  '/city/bhiwani',
#  '/city/bhopal',
#  '/city/bhubaneswar',
#  '/city/bhuj',
#  '/city/bhusawal',
#  '/city/bidar',
#  '/city/biharsharif',
#  '/city/bijapur',
#  '/city/bijnor',
#  '/city/bikaner',
#  '/city/bilaspur',
#  '/city/bilaspur-hp',
#  '/city/bilimora',
#  '/city/biswanath-chariali',
#  '/city/bodhan-rural',
#  '/city/bodinayakanur',
#  '/city/boisar',
#  '/city/bokaro',
#  '/city/bolpur',
#  '/city/bongaigaon',
#  '/city/bongaon',
#  '/city/budaun',
#  '/city/budhwal',
#  '/city/bulandshahr',
#  '/city/buldana',
#  '/city/bundi',
#  '/city/burhanpur',
#  '/city/buxar',
#  '/city/central-goa',
#  '/city/chaibasa',
#  '/city/chakdaha',
#  '/city/chalakkudy',
#  '/city/chalisgaon',
#  '/city/chandausi',
#  '/city/chandigarh',
#  '/city/chandrapur',
#  '/city/changanassery',
#  '/city/charkhi-dadri_perm_closed_8june22',
#  '/city/chengannur',
#  '/city/chennai',
#  '/city/chhapra',
#  '/city/chhatarpur',
#  '/city/chhindwara',
#  '/city/chidambaram',
#  '/city/chikhli',
#  '/city/chikkaballapur',
#  '/city/chikmagalur',
#  '/city/chiplun',
#  '/city/chitradurga',
#  '/city/chittoor',
#  '/city/chittorgarh',
#  '/city/chopda',
#  '/city/churu',
#  '/city/coimbatore',
#  '/city/cooch-behar',
#  '/city/cuddalore',
#  '/city/cuttack',
#  '/city/dahanu',
#  '/city/dahod',
#  '/city/daltonganj',
#  '/city/daman',
#  '/city/darbhanga',
#  '/city/darjeeling',
#  '/city/daund',
#  '/city/dausa',
#  '/city/davanagere',
#  '/city/dehradun',
#  '/city/dehri',
#  '/city/delhi',
#  '/city/deoghar',
#  '/city/dewas',
#  '/city/dhanbad',
#  '/city/dhar',
#  '/city/dharamshala',
#  '/city/dharapuram',
#  '/city/dharmapuri',
#  '/city/dharwad',
#  '/city/dholpur',
#  '/city/dhoraji',
#  '/city/dhule',
#  '/city/dibrugarh',
#  '/city/digboi',
#  '/city/dimapur',
#  '/city/dindigul',
#  '/city/diu',
#  '/city/doddaballapura',
#  '/city/duliajan',
#  '/city/dumka',
#  '/city/dungarpur',
#  '/city/durgapur',
#  '/city/dwarka',
#  '/city/eluru',
#  '/city/erode',
#  '/city/etah',
#  '/city/etawah',
#  '/city/faizabad',
#  '/city/faridabad',
#  '/city/faridkot',
#  '/city/farrukhabad',
#  '/city/fatehabad',
#  '/city/fatehgarh-sahib',
#  '/city/fatehpur',
#  '/city/fazilka',
#  '/city/firozabad',
#  '/city/firozpur',
#  '/city/gadag-betigeri',
#  '/city/gadwal',
#  '/city/gandhidham',
#  '/city/gangapur-city',
#  '/city/gangarampur',
#  '/city/gangtok',
#  '/city/gauriganj',
#  '/city/gaya',
#  '/city/giridih',
#  '/city/godhra',
#  '/city/gokak',
#  '/city/golaghat',
#  '/city/gonda',
#  '/city/gondal',
#  '/city/gondia',
#  '/city/gopalganj',
#  '/city/gorakhpur',
#  '/city/gudivada',
#  '/city/guna',
#  '/city/guntakal',
#  '/city/guntur',
#  '/city/gurdaspur',
#  '/city/gurgaon',
#  '/city/guwahati',
#  '/city/gwalior',
#  '/city/habra',
#  '/city/hajipur',
#  '/city/haldia',
#  '/city/haldwani',
#  '/city/halol',
#  '/city/hamirpur',
#  '/city/hampi',
#  '/city/hansi',
#  '/city/hanumangarh',
#  '/city/hapur',
#  '/city/hardoi',
#  '/city/haridwar',
#  '/city/hassan',
#  '/city/hathras',
#  '/city/haveri',
#  '/city/himmatnagar',
#  '/city/hindaun',
#  '/city/hinganghat',
#  '/city/hisar',
#  '/city/hoshangabad',
#  '/city/hoshiarpur',
#  '/city/hospet',
#  '/city/hosur',
#  '/city/hubli',
#  '/city/hyderabad',
#  '/city/ichalkaranji',
#  '/city/idukki',
#  '/city/imphal',
#  '/city/indore',
#  '/city/irinjalakuda',
#  '/city/itanagar',
#  '/city/itarsi',
#  '/city/jabalpur',
#  '/city/jagdalpur',
#  '/city/jagraon',
#  '/city/jagtial',
#  '/city/jahanabad',
#  '/city/jaigaon',
#  '/city/jaipur',
#  '/city/jalandhar',
#  '/city/jalaun',
#  '/city/jalgaon',
#  '/city/jalpaiguri',
#  '/city/jammu',
#  '/city/jamnagar',
#  '/city/jamshedpur',
#  '/city/jaunpur',
#  '/city/jhalawar',
#  '/city/jhansi',
#  '/city/jhargram',
#  '/city/jhunjhunu',
#  '/city/jind',
#  '/city/jjajjar',
#  '/city/jodhpur',
#  '/city/jorhat',
#  '/city/junagadh',
#  '/city/kadapa',
#  '/city/kadayanallur',
#  '/city/kadi',
#  '/city/kadiri',
#  '/city/kaithal',
#  '/city/kakinada',
#  '/city/kalaburagi',
#  '/city/kalady',
#  '/city/kalna',
#  '/city/kamareddy',
#  '/city/kanchrapara',
#  '/city/kannauj',
#  '/city/kannur',
#  '/city/kanpur',
#  '/city/kanyakumari',
#  '/city/kapurthala',
#  '/city/karad',
#  '/city/karaikal',
#  '/city/karaikkudi',
#  '/city/karimnagar',
#  '/city/karnal',
#  '/city/karunagappaly',
#  '/city/karur',
#  '/city/karwar',
#  '/city/kasaragod',
#  '/city/kashipur',
#  '/city/katihar',
#  '/city/katni',
#  '/city/kavali',
#  '/city/kayamkulam',
#  '/city/kendrapada',
#  '/city/kendujhar',
#  '/city/khalilabad',
#  '/city/khamgaon',
#  '/city/khammam',
#  '/city/khandwa',
#  '/city/khanna',
#  '/city/kharagpur',
#  '/city/khopoli',
#  '/city/kishanganj',
#  '/city/kishangarh',
#  '/city/kochi',
#  '/city/kodaikanal',
#  '/city/kohima',
#  '/city/kokrajhar',
#  '/city/kolar',
#  '/city/kolhapur',
#  '/city/kolkata',
#  '/city/kollam',
#  '/city/kopargaon',
#  '/city/koppal',
#  '/city/korba',
#  '/city/kota',
#  '/city/kotdwar',
#  '/city/kothagudem',
#  '/city/kothamanagalam',
#  '/city/kottakkal',
#  '/city/kottarakkara',
#  '/city/kottayam',
#  '/city/kovilpatti',
#  '/city/kozhikode',
#  '/city/krishnagiri',
#  '/city/krishnanagar',
#  '/city/kullu',
#  '/city/kumarakom',
#  '/city/kumbakonam',
#  '/city/kumta',
#  '/city/kundapura',
#  '/city/kunnamkullam',
#  '/city/kurnool',
#  '/city/kurukshetra',
#  '/city/kushalnagar',
#  '/city/lakhimpur',
#  '/city/lalitpur',
#  '/city/latur',
#  '/city/lonavala',
#  '/city/lonavla',
#  '/city/lucknow',
#  '/city/ludhiana',
#  '/city/machilipatnam',
#  '/city/madanapalle',
#  '/city/madhubani',
#  '/city/madikeri',
#  '/city/madurai',
#  '/city/mahabaleshwar',
#  '/city/mahbubnagar',
#  '/city/mahoba',
#  '/city/malappuram',
#  '/city/malda',
#  '/city/malegaon',
#  '/city/malout',
#  '/city/manali',
#  '/city/mancherial',
#  '/city/mandi-dabwali',
#  '/city/mandi-gobindgarh',
#  '/city/mandi-hp',
#  '/city/mandsaur',
#  '/city/mandya',
#  '/city/mangaluru',
#  '/city/manipal',
#  '/city/manjeri',
#  '/city/mannargudi',
#  '/city/mansa',
#  '/city/markapur',
#  '/city/mathura',
#  '/city/maunath-bhanjan',
#  '/city/mayiladuthurai',
#  '/city/medinipur',
#  '/city/meerut',
#  '/city/mehsana',
#  '/city/mettupalayam',
#  '/city/miryalaguda',
#  '/city/mirzapur',
#  '/city/modinagar',
#  '/city/moga',
#  '/city/moodbidri',
#  '/city/moradabad',
#  '/city/morbi',
#  '/city/morena',
#  '/city/motihari',
#  '/city/mount-abu',
#  '/city/mughalsarai',
#  '/city/mukerian',
#  '/city/muktsar',
#  '/city/mumbai',
#  '/city/munger',
#  '/city/murshidabad',
#  '/city/mussoorie',
#  '/city/muvattupuzha',
#  '/city/muzaffarnagar',
#  '/city/muzaffarpur',
#  '/city/mysore',
#  '/city/nabadwip',
#  '/city/nadiad',
#  '/city/nagaon',
#  '/city/nagapattinam',
#  '/city/nagda',
#  '/city/nagercoil',
#  '/city/nagpur',
#  '/city/nagur',
#  '/city/naharlagun',
#  '/city/nainital',
#  '/city/nalbari',
#  '/city/nalgonda',
#  '/city/namakkal',
#  '/city/nanded',
#  '/city/nandurbar',
#  '/city/nandyal',
#  '/city/nangal',
#  '/city/naraingarh',
#  '/city/narasaraopet',
#  '/city/narnaul',
#  '/city/narsinghpur',
#  '/city/narsipatnam',
#  '/city/nashik',
#  '/city/navsari',
#  '/city/neemuch',
#  '/city/nellore',
#  '/city/neyveli',
#  '/city/nipani',
#  '/city/nirmal',
#  '/city/nizamabad',
#  '/city/noida',
#  '/city/noida-1',
#  '/city/north-goa',
#  '/city/ongole',
#  '/city/ooty',
#  '/city/orai',
#  '/city/osmanabad',
#  '/city/pala',
#  '/city/palakkad',
#  '/city/palakollu',
#  '/city/palampur',
#  '/city/palani',
#  '/city/palanpur',
#  '/city/palghar',
#  '/city/pali',
#  '/city/palwal',
#  '/city/panchgani',
#  '/city/panipat',
#  '/city/paramakudi',
#  '/city/parbhani',
#  '/city/pathankot',
#  '/city/patiala',
#  '/city/patna',
#  '/city/pattukkottai',
#  '/city/payyannur',
#  '/city/perambalur',
#  '/city/perinthalmanna',
#  '/city/phagwara',
#  '/city/phusro',
#  '/city/pilani',
#  '/city/pilibhit',
#  '/city/pinjore-city',
#  '/city/pondicherry',
#  '/city/porbandar',
#  '/city/port-blair',
#  '/city/pratapgarh',
#  '/city/proddatur',
#  '/city/pudukkottai',
#  '/city/pune',
#  '/city/puri',
#  '/city/purnea',
#  '/city/purulia',
#  '/city/pusad',
#  '/city/puttur',
#  '/city/puttur-karnataka',
#  '/city/rae-bareli',
#  '/city/raghunathpur',
#  '/city/raichur',
#  '/city/raiganj',
#  '/city/raigarh',
#  '/city/raipur',
#  '/city/rajahmundry',
#  '/city/rajapalayam',
#  '/city/rajgarh',
#  '/city/rajkot',
#  '/city/rajnandgaon',
#  '/city/rajsamand',
#  '/city/ramagundam',
#  '/city/ramanagara',
#  '/city/ramanathapuram',
#  '/city/ramgarh',
#  '/city/rampur',
#  '/city/ranaghat',
#  '/city/ranaghat-wb',
#  '/city/ranchi',
#  '/city/rangia',
#  '/city/rangpo',
#  '/city/ranibennur',
#  '/city/raniganj',
#  '/city/ratlam',
#  '/city/ratnagiri',
#  '/city/ravulapalem',
#  '/city/rayachoty',
#  '/city/rewa',
#  '/city/rewari',
#  '/city/rishikesh',
#  '/city/rohtak',
#  '/city/roorkee',
#  '/city/ropar',
#  '/city/rourkela',
#  '/city/rudrapur',
#  '/city/sagar',
#  '/city/saharsa',
#  '/city/salem',
#  '/city/samastipur',
#  '/city/sambalpur',
#  '/city/sangamner',
#  '/city/sangli',
#  '/city/sangrur',
#  '/city/santipur',
#  '/city/saputara',
#  '/city/sasaram',
#  '/city/satara',
#  '/city/satna',
#  '/city/sawai-madhopur',
#  '/city/sawantwadi',
#  '/city/sehore',
#  '/city/shahdol',
#  '/city/shahjahanpur',
#  '/city/shamli',
#  '/city/shikohabad',
#  '/city/shillong',
#  '/city/shimla',
#  '/city/shirdi-city',
#  '/city/shivamogga',
#  '/city/shivpuri',
#  '/city/shravasti',
#  '/city/shrirampur',
#  '/city/siddipet',
#  '/city/sikar',
#  '/city/silchar',
#  '/city/siliguri',
#  '/city/silvassa',
#  '/city/sindhanur',
#  '/city/singrauli',
#  '/city/sirkali',
#  '/city/sirsa',
#  '/city/sirsi',
#  '/city/sitamarhi',
#  '/city/sitapur',
#  '/city/sivakasi',
#  '/city/sivasagar',
#  '/city/siwan',
#  '/city/solan',
#  '/city/solapur',
#  '/city/sonipat',
#  '/city/south-goa',
#  '/city/sri-ganganagar',
#  '/city/srikakulam',
#  '/city/srivilliputhur',
#  '/city/sultanpur',
#  '/city/surat',
#  '/city/suratgarh',
#  '/city/surendranagar-dudhrej',
#  '/city/suri',
#  '/city/suryapet',
#  '/city/tadepalligudem',
#  '/city/tadpatri',
#  '/city/taliparambu',
#  '/city/tanuku',
#  '/city/tarn-taran-sahib',
#  '/city/tenkasi',
#  '/city/tezpur',
#  '/city/thalassery',
#  '/city/thanjavur',
#  '/city/theni',
#  '/city/thiruvalla',
#  '/city/thiruvallur',
#  '/city/thiruvananthapuram',
#  '/city/thiruvarur',
#  '/city/thodupuzha',
#  '/city/thoothukudi',
#  '/city/thrissur',
#  '/city/tindivanam',
#  '/city/tinsukia',
#  '/city/tiptur',
#  '/city/tirunelveli',
#  '/city/tirupati',
#  '/city/tirupur',
#  '/city/tiruttani',
#  '/city/tiruvannamalai',
#  '/city/tohana',
#  '/city/trichy',
#  '/city/tumakuru',
#  '/city/tuni',
#  '/city/udaipur',
#  '/city/udgir',
#  '/city/udhampur',
#  '/city/ujjain',
#  '/city/uluberia',
#  '/city/una',
#  '/city/unnao',
#  '/city/uran-islampur',
#  '/city/vadodara',
#  '/city/valsad',
#  '/city/vapi',
#  '/city/varanasi',
#  '/city/varkala',
#  '/city/vellore',
#  '/city/veraval',
#  '/city/vidisha',
#  '/city/vijayawada',
#  '/city/viluppuram',
#  '/city/virudhunagar',
#  '/city/visnagar',
#  '/city/vizag',
#  '/city/vizianagaram',
#  '/city/vyara',
#  '/city/waidhan',
#  '/city/warangal',
#  '/city/wardha',
#  '/city/washim',
#  '/city/wayanad',
#  '/city/yamuna-nagar',
#  '/city/yavatmal',
#  '/']

# %%
urls[0:33]
# Out:
# ['/ahmedabad',
#  '/bangalore',
#  '/chennai',
#  '/delhi',
#  '/gurgaon',
#  '/hyderabad',
#  '/kolkata',
#  '/mumbai',
#  '/pune',
#  '#city-links',
#  'https://play.google.com/store/apps/details?id=in.swiggy.android',
#  'https://itunes.apple.com/in/app/swiggy-food-order-delivery/id989540920',
#  '/about',
#  '/team',
#  '/careers',
#  'https://blog.swiggy.com',
#  '/bug-bounty',
#  '/swiggy-super',
#  'https://corporate.swiggy.com',
#  '/swiggy-instamart',
#  '/support',
#  'https://partner-with-us.swiggy.com/onboard#/swiggy',
#  'https://ride.swiggy.com/',
#  '/terms-and-conditions',
#  '/refund-policy',
#  '/privacy-policy',
#  '/cookie-policy',
#  '/offer-terms',
#  '/beware-of-phishing-and-fraud',
#  '/tnc-corporate-sm',
#  '/tnc-corporate-discount',
#  'https://itunes.apple.com/in/app/id989540920?referrer=utm_source%3Dswiggy%26utm_medium%3Dhomepage',
#  'https://play.google.com/store/apps/details?id=in.swiggy.android&referrer=utm_source%3Dswiggy%26utm_medium%3Dheader']

# %%
del urls[0:33]

# %%
urls
# Out:
# ['/city/abohar',
#  '/city/adilabad',
#  '/city/adityapur',
#  '/city/adoni',
#  '/city/agartala',
#  '/city/agra',
#  '/city/ahmedabad',
#  '/city/ahmednagar',
#  '/city/aizawl',
#  '/city/ajmer',
#  '/city/akola',
#  '/city/alappuzha',
#  '/city/aligarh',
#  '/city/alipurduar',
#  '/city/allahabad',
#  '/city/almora',
#  '/city/alwar',
#  '/city/amalapuram',
#  '/city/ambala',
#  '/city/ambejogai',
#  '/city/ambikapur',
#  '/city/ambur',
#  '/city/amravati',
#  '/city/amreli',
#  '/city/amritsar',
#  '/city/anand',
#  '/city/anantapur',
#  '/city/angul',
#  '/city/ankleshwar',
#  '/city/arakkonam',
#  '/city/arambagh',
#  '/city/arrah',
#  '/city/aruppukottai',
#  '/city/asansol',
#  '/city/aurangabad',
#  '/city/aurangabad_bihar',
#  '/city/azamgarh',
#  '/city/baddi',
#  '/city/bagalkot',
#  '/city/bagdogra',
#  '/city/bagula',
#  '/city/bahadurgarh',
#  '/city/bahraich',
#  '/city/balaghat',
#  '/city/balangir',
#  '/city/balasore',
#  '/city/ballari',
#  '/city/balrampur',
#  '/city/balurghat',
#  '/city/banda',
#  '/city/bangalore',
#  '/city/bankabihar',
#  '/city/bankura',
#  '/city/bantwal',
#  '/city/bapatlachirala',
#  '/city/baramati',
#  '/city/baran',
#  '/city/baraut',
#  '/city/bardhaman',
#  '/city/bardoli',
#  '/city/bareilly',
#  '/city/barh',
#  '/city/baripada',
#  '/city/barmer',
#  '/city/barnala',
#  '/city/barshi',
#  '/city/barwani',
#  '/city/basirhat',
#  '/city/basti',
#  '/city/batala',
#  '/city/bathinda',
#  '/city/beawar',
#  '/city/beed',
#  '/city/begusarai',
#  '/city/bela-pratapgarh',
#  '/city/belgaum',
#  '/city/berhampore',
#  '/city/berhampur',
#  '/city/bettiah',
#  '/city/betul',
#  '/city/bhadohi',
#  '/city/bhadrachalam',
#  '/city/bhadrak',
#  '/city/bhadravati',
#  '/city/bhagalpur',
#  '/city/bhandara',
#  '/city/bharabanki',
#  '/city/bharatpur',
#  '/city/bharuch',
#  '/city/bhatkal',
#  '/city/bhavnagar',
#  '/city/bhawanipatna',
#  '/city/bhilai',
#  '/city/bhilwara',
#  '/city/bhimavaram',
#  '/city/bhind',
#  '/city/bhiwadi',
#  '/city/bhiwani',
#  '/city/bhopal',
#  '/city/bhubaneswar',
#  '/city/bhuj',
#  '/city/bhusawal',
#  '/city/bidar',
#  '/city/biharsharif',
#  '/city/bijapur',
#  '/city/bijnor',
#  '/city/bikaner',
#  '/city/bilaspur',
#  '/city/bilaspur-hp',
#  '/city/bilimora',
#  '/city/biswanath-chariali',
#  '/city/bodhan-rural',
#  '/city/bodinayakanur',
#  '/city/boisar',
#  '/city/bokaro',
#  '/city/bolpur',
#  '/city/bongaigaon',
#  '/city/bongaon',
#  '/city/budaun',
#  '/city/budhwal',
#  '/city/bulandshahr',
#  '/city/buldana',
#  '/city/bundi',
#  '/city/burhanpur',
#  '/city/buxar',
#  '/city/central-goa',
#  '/city/chaibasa',
#  '/city/chakdaha',
#  '/city/chalakkudy',
#  '/city/chalisgaon',
#  '/city/chandausi',
#  '/city/chandigarh',
#  '/city/chandrapur',
#  '/city/changanassery',
#  '/city/charkhi-dadri_perm_closed_8june22',
#  '/city/chengannur',
#  '/city/chennai',
#  '/city/chhapra',
#  '/city/chhatarpur',
#  '/city/chhindwara',
#  '/city/chidambaram',
#  '/city/chikhli',
#  '/city/chikkaballapur',
#  '/city/chikmagalur',
#  '/city/chiplun',
#  '/city/chitradurga',
#  '/city/chittoor',
#  '/city/chittorgarh',
#  '/city/chopda',
#  '/city/churu',
#  '/city/coimbatore',
#  '/city/cooch-behar',
#  '/city/cuddalore',
#  '/city/cuttack',
#  '/city/dahanu',
#  '/city/dahod',
#  '/city/daltonganj',
#  '/city/daman',
#  '/city/darbhanga',
#  '/city/darjeeling',
#  '/city/daund',
#  '/city/dausa',
#  '/city/davanagere',
#  '/city/dehradun',
#  '/city/dehri',
#  '/city/delhi',
#  '/city/deoghar',
#  '/city/dewas',
#  '/city/dhanbad',
#  '/city/dhar',
#  '/city/dharamshala',
#  '/city/dharapuram',
#  '/city/dharmapuri',
#  '/city/dharwad',
#  '/city/dholpur',
#  '/city/dhoraji',
#  '/city/dhule',
#  '/city/dibrugarh',
#  '/city/digboi',
#  '/city/dimapur',
#  '/city/dindigul',
#  '/city/diu',
#  '/city/doddaballapura',
#  '/city/duliajan',
#  '/city/dumka',
#  '/city/dungarpur',
#  '/city/durgapur',
#  '/city/dwarka',
#  '/city/eluru',
#  '/city/erode',
#  '/city/etah',
#  '/city/etawah',
#  '/city/faizabad',
#  '/city/faridabad',
#  '/city/faridkot',
#  '/city/farrukhabad',
#  '/city/fatehabad',
#  '/city/fatehgarh-sahib',
#  '/city/fatehpur',
#  '/city/fazilka',
#  '/city/firozabad',
#  '/city/firozpur',
#  '/city/gadag-betigeri',
#  '/city/gadwal',
#  '/city/gandhidham',
#  '/city/gangapur-city',
#  '/city/gangarampur',
#  '/city/gangtok',
#  '/city/gauriganj',
#  '/city/gaya',
#  '/city/giridih',
#  '/city/godhra',
#  '/city/gokak',
#  '/city/golaghat',
#  '/city/gonda',
#  '/city/gondal',
#  '/city/gondia',
#  '/city/gopalganj',
#  '/city/gorakhpur',
#  '/city/gudivada',
#  '/city/guna',
#  '/city/guntakal',
#  '/city/guntur',
#  '/city/gurdaspur',
#  '/city/gurgaon',
#  '/city/guwahati',
#  '/city/gwalior',
#  '/city/habra',
#  '/city/hajipur',
#  '/city/haldia',
#  '/city/haldwani',
#  '/city/halol',
#  '/city/hamirpur',
#  '/city/hampi',
#  '/city/hansi',
#  '/city/hanumangarh',
#  '/city/hapur',
#  '/city/hardoi',
#  '/city/haridwar',
#  '/city/hassan',
#  '/city/hathras',
#  '/city/haveri',
#  '/city/himmatnagar',
#  '/city/hindaun',
#  '/city/hinganghat',
#  '/city/hisar',
#  '/city/hoshangabad',
#  '/city/hoshiarpur',
#  '/city/hospet',
#  '/city/hosur',
#  '/city/hubli',
#  '/city/hyderabad',
#  '/city/ichalkaranji',
#  '/city/idukki',
#  '/city/imphal',
#  '/city/indore',
#  '/city/irinjalakuda',
#  '/city/itanagar',
#  '/city/itarsi',
#  '/city/jabalpur',
#  '/city/jagdalpur',
#  '/city/jagraon',
#  '/city/jagtial',
#  '/city/jahanabad',
#  '/city/jaigaon',
#  '/city/jaipur',
#  '/city/jalandhar',
#  '/city/jalaun',
#  '/city/jalgaon',
#  '/city/jalpaiguri',
#  '/city/jammu',
#  '/city/jamnagar',
#  '/city/jamshedpur',
#  '/city/jaunpur',
#  '/city/jhalawar',
#  '/city/jhansi',
#  '/city/jhargram',
#  '/city/jhunjhunu',
#  '/city/jind',
#  '/city/jjajjar',
#  '/city/jodhpur',
#  '/city/jorhat',
#  '/city/junagadh',
#  '/city/kadapa',
#  '/city/kadayanallur',
#  '/city/kadi',
#  '/city/kadiri',
#  '/city/kaithal',
#  '/city/kakinada',
#  '/city/kalaburagi',
#  '/city/kalady',
#  '/city/kalna',
#  '/city/kamareddy',
#  '/city/kanchrapara',
#  '/city/kannauj',
#  '/city/kannur',
#  '/city/kanpur',
#  '/city/kanyakumari',
#  '/city/kapurthala',
#  '/city/karad',
#  '/city/karaikal',
#  '/city/karaikkudi',
#  '/city/karimnagar',
#  '/city/karnal',
#  '/city/karunagappaly',
#  '/city/karur',
#  '/city/karwar',
#  '/city/kasaragod',
#  '/city/kashipur',
#  '/city/katihar',
#  '/city/katni',
#  '/city/kavali',
#  '/city/kayamkulam',
#  '/city/kendrapada',
#  '/city/kendujhar',
#  '/city/khalilabad',
#  '/city/khamgaon',
#  '/city/khammam',
#  '/city/khandwa',
#  '/city/khanna',
#  '/city/kharagpur',
#  '/city/khopoli',
#  '/city/kishanganj',
#  '/city/kishangarh',
#  '/city/kochi',
#  '/city/kodaikanal',
#  '/city/kohima',
#  '/city/kokrajhar',
#  '/city/kolar',
#  '/city/kolhapur',
#  '/city/kolkata',
#  '/city/kollam',
#  '/city/kopargaon',
#  '/city/koppal',
#  '/city/korba',
#  '/city/kota',
#  '/city/kotdwar',
#  '/city/kothagudem',
#  '/city/kothamanagalam',
#  '/city/kottakkal',
#  '/city/kottarakkara',
#  '/city/kottayam',
#  '/city/kovilpatti',
#  '/city/kozhikode',
#  '/city/krishnagiri',
#  '/city/krishnanagar',
#  '/city/kullu',
#  '/city/kumarakom',
#  '/city/kumbakonam',
#  '/city/kumta',
#  '/city/kundapura',
#  '/city/kunnamkullam',
#  '/city/kurnool',
#  '/city/kurukshetra',
#  '/city/kushalnagar',
#  '/city/lakhimpur',
#  '/city/lalitpur',
#  '/city/latur',
#  '/city/lonavala',
#  '/city/lonavla',
#  '/city/lucknow',
#  '/city/ludhiana',
#  '/city/machilipatnam',
#  '/city/madanapalle',
#  '/city/madhubani',
#  '/city/madikeri',
#  '/city/madurai',
#  '/city/mahabaleshwar',
#  '/city/mahbubnagar',
#  '/city/mahoba',
#  '/city/malappuram',
#  '/city/malda',
#  '/city/malegaon',
#  '/city/malout',
#  '/city/manali',
#  '/city/mancherial',
#  '/city/mandi-dabwali',
#  '/city/mandi-gobindgarh',
#  '/city/mandi-hp',
#  '/city/mandsaur',
#  '/city/mandya',
#  '/city/mangaluru',
#  '/city/manipal',
#  '/city/manjeri',
#  '/city/mannargudi',
#  '/city/mansa',
#  '/city/markapur',
#  '/city/mathura',
#  '/city/maunath-bhanjan',
#  '/city/mayiladuthurai',
#  '/city/medinipur',
#  '/city/meerut',
#  '/city/mehsana',
#  '/city/mettupalayam',
#  '/city/miryalaguda',
#  '/city/mirzapur',
#  '/city/modinagar',
#  '/city/moga',
#  '/city/moodbidri',
#  '/city/moradabad',
#  '/city/morbi',
#  '/city/morena',
#  '/city/motihari',
#  '/city/mount-abu',
#  '/city/mughalsarai',
#  '/city/mukerian',
#  '/city/muktsar',
#  '/city/mumbai',
#  '/city/munger',
#  '/city/murshidabad',
#  '/city/mussoorie',
#  '/city/muvattupuzha',
#  '/city/muzaffarnagar',
#  '/city/muzaffarpur',
#  '/city/mysore',
#  '/city/nabadwip',
#  '/city/nadiad',
#  '/city/nagaon',
#  '/city/nagapattinam',
#  '/city/nagda',
#  '/city/nagercoil',
#  '/city/nagpur',
#  '/city/nagur',
#  '/city/naharlagun',
#  '/city/nainital',
#  '/city/nalbari',
#  '/city/nalgonda',
#  '/city/namakkal',
#  '/city/nanded',
#  '/city/nandurbar',
#  '/city/nandyal',
#  '/city/nangal',
#  '/city/naraingarh',
#  '/city/narasaraopet',
#  '/city/narnaul',
#  '/city/narsinghpur',
#  '/city/narsipatnam',
#  '/city/nashik',
#  '/city/navsari',
#  '/city/neemuch',
#  '/city/nellore',
#  '/city/neyveli',
#  '/city/nipani',
#  '/city/nirmal',
#  '/city/nizamabad',
#  '/city/noida',
#  '/city/noida-1',
#  '/city/north-goa',
#  '/city/ongole',
#  '/city/ooty',
#  '/city/orai',
#  '/city/osmanabad',
#  '/city/pala',
#  '/city/palakkad',
#  '/city/palakollu',
#  '/city/palampur',
#  '/city/palani',
#  '/city/palanpur',
#  '/city/palghar',
#  '/city/pali',
#  '/city/palwal',
#  '/city/panchgani',
#  '/city/panipat',
#  '/city/paramakudi',
#  '/city/parbhani',
#  '/city/pathankot',
#  '/city/patiala',
#  '/city/patna',
#  '/city/pattukkottai',
#  '/city/payyannur',
#  '/city/perambalur',
#  '/city/perinthalmanna',
#  '/city/phagwara',
#  '/city/phusro',
#  '/city/pilani',
#  '/city/pilibhit',
#  '/city/pinjore-city',
#  '/city/pondicherry',
#  '/city/porbandar',
#  '/city/port-blair',
#  '/city/pratapgarh',
#  '/city/proddatur',
#  '/city/pudukkottai',
#  '/city/pune',
#  '/city/puri',
#  '/city/purnea',
#  '/city/purulia',
#  '/city/pusad',
#  '/city/puttur',
#  '/city/puttur-karnataka',
#  '/city/rae-bareli',
#  '/city/raghunathpur',
#  '/city/raichur',
#  '/city/raiganj',
#  '/city/raigarh',
#  '/city/raipur',
#  '/city/rajahmundry',
#  '/city/rajapalayam',
#  '/city/rajgarh',
#  '/city/rajkot',
#  '/city/rajnandgaon',
#  '/city/rajsamand',
#  '/city/ramagundam',
#  '/city/ramanagara',
#  '/city/ramanathapuram',
#  '/city/ramgarh',
#  '/city/rampur',
#  '/city/ranaghat',
#  '/city/ranaghat-wb',
#  '/city/ranchi',
#  '/city/rangia',
#  '/city/rangpo',
#  '/city/ranibennur',
#  '/city/raniganj',
#  '/city/ratlam',
#  '/city/ratnagiri',
#  '/city/ravulapalem',
#  '/city/rayachoty',
#  '/city/rewa',
#  '/city/rewari',
#  '/city/rishikesh',
#  '/city/rohtak',
#  '/city/roorkee',
#  '/city/ropar',
#  '/city/rourkela',
#  '/city/rudrapur',
#  '/city/sagar',
#  '/city/saharsa',
#  '/city/salem',
#  '/city/samastipur',
#  '/city/sambalpur',
#  '/city/sangamner',
#  '/city/sangli',
#  '/city/sangrur',
#  '/city/santipur',
#  '/city/saputara',
#  '/city/sasaram',
#  '/city/satara',
#  '/city/satna',
#  '/city/sawai-madhopur',
#  '/city/sawantwadi',
#  '/city/sehore',
#  '/city/shahdol',
#  '/city/shahjahanpur',
#  '/city/shamli',
#  '/city/shikohabad',
#  '/city/shillong',
#  '/city/shimla',
#  '/city/shirdi-city',
#  '/city/shivamogga',
#  '/city/shivpuri',
#  '/city/shravasti',
#  '/city/shrirampur',
#  '/city/siddipet',
#  '/city/sikar',
#  '/city/silchar',
#  '/city/siliguri',
#  '/city/silvassa',
#  '/city/sindhanur',
#  '/city/singrauli',
#  '/city/sirkali',
#  '/city/sirsa',
#  '/city/sirsi',
#  '/city/sitamarhi',
#  '/city/sitapur',
#  '/city/sivakasi',
#  '/city/sivasagar',
#  '/city/siwan',
#  '/city/solan',
#  '/city/solapur',
#  '/city/sonipat',
#  '/city/south-goa',
#  '/city/sri-ganganagar',
#  '/city/srikakulam',
#  '/city/srivilliputhur',
#  '/city/sultanpur',
#  '/city/surat',
#  '/city/suratgarh',
#  '/city/surendranagar-dudhrej',
#  '/city/suri',
#  '/city/suryapet',
#  '/city/tadepalligudem',
#  '/city/tadpatri',
#  '/city/taliparambu',
#  '/city/tanuku',
#  '/city/tarn-taran-sahib',
#  '/city/tenkasi',
#  '/city/tezpur',
#  '/city/thalassery',
#  '/city/thanjavur',
#  '/city/theni',
#  '/city/thiruvalla',
#  '/city/thiruvallur',
#  '/city/thiruvananthapuram',
#  '/city/thiruvarur',
#  '/city/thodupuzha',
#  '/city/thoothukudi',
#  '/city/thrissur',
#  '/city/tindivanam',
#  '/city/tinsukia',
#  '/city/tiptur',
#  '/city/tirunelveli',
#  '/city/tirupati',
#  '/city/tirupur',
#  '/city/tiruttani',
#  '/city/tiruvannamalai',
#  '/city/tohana',
#  '/city/trichy',
#  '/city/tumakuru',
#  '/city/tuni',
#  '/city/udaipur',
#  '/city/udgir',
#  '/city/udhampur',
#  '/city/ujjain',
#  '/city/uluberia',
#  '/city/una',
#  '/city/unnao',
#  '/city/uran-islampur',
#  '/city/vadodara',
#  '/city/valsad',
#  '/city/vapi',
#  '/city/varanasi',
#  '/city/varkala',
#  '/city/vellore',
#  '/city/veraval',
#  '/city/vidisha',
#  '/city/vijayawada',
#  '/city/viluppuram',
#  '/city/virudhunagar',
#  '/city/visnagar',
#  '/city/vizag',
#  '/city/vizianagaram',
#  '/city/vyara',
#  '/city/waidhan',
#  '/city/warangal',
#  '/city/wardha',
#  '/city/washim',
#  '/city/wayanad',
#  '/city/yamuna-nagar',
#  '/city/yavatmal',
#  '/']

# %%
del urls[-1]

# %%
urls
# Out:
# ['/city/abohar',
#  '/city/adilabad',
#  '/city/adityapur',
#  '/city/adoni',
#  '/city/agartala',
#  '/city/agra',
#  '/city/ahmedabad',
#  '/city/ahmednagar',
#  '/city/aizawl',
#  '/city/ajmer',
#  '/city/akola',
#  '/city/alappuzha',
#  '/city/aligarh',
#  '/city/alipurduar',
#  '/city/allahabad',
#  '/city/almora',
#  '/city/alwar',
#  '/city/amalapuram',
#  '/city/ambala',
#  '/city/ambejogai',
#  '/city/ambikapur',
#  '/city/ambur',
#  '/city/amravati',
#  '/city/amreli',
#  '/city/amritsar',
#  '/city/anand',
#  '/city/anantapur',
#  '/city/angul',
#  '/city/ankleshwar',
#  '/city/arakkonam',
#  '/city/arambagh',
#  '/city/arrah',
#  '/city/aruppukottai',
#  '/city/asansol',
#  '/city/aurangabad',
#  '/city/aurangabad_bihar',
#  '/city/azamgarh',
#  '/city/baddi',
#  '/city/bagalkot',
#  '/city/bagdogra',
#  '/city/bagula',
#  '/city/bahadurgarh',
#  '/city/bahraich',
#  '/city/balaghat',
#  '/city/balangir',
#  '/city/balasore',
#  '/city/ballari',
#  '/city/balrampur',
#  '/city/balurghat',
#  '/city/banda',
#  '/city/bangalore',
#  '/city/bankabihar',
#  '/city/bankura',
#  '/city/bantwal',
#  '/city/bapatlachirala',
#  '/city/baramati',
#  '/city/baran',
#  '/city/baraut',
#  '/city/bardhaman',
#  '/city/bardoli',
#  '/city/bareilly',
#  '/city/barh',
#  '/city/baripada',
#  '/city/barmer',
#  '/city/barnala',
#  '/city/barshi',
#  '/city/barwani',
#  '/city/basirhat',
#  '/city/basti',
#  '/city/batala',
#  '/city/bathinda',
#  '/city/beawar',
#  '/city/beed',
#  '/city/begusarai',
#  '/city/bela-pratapgarh',
#  '/city/belgaum',
#  '/city/berhampore',
#  '/city/berhampur',
#  '/city/bettiah',
#  '/city/betul',
#  '/city/bhadohi',
#  '/city/bhadrachalam',
#  '/city/bhadrak',
#  '/city/bhadravati',
#  '/city/bhagalpur',
#  '/city/bhandara',
#  '/city/bharabanki',
#  '/city/bharatpur',
#  '/city/bharuch',
#  '/city/bhatkal',
#  '/city/bhavnagar',
#  '/city/bhawanipatna',
#  '/city/bhilai',
#  '/city/bhilwara',
#  '/city/bhimavaram',
#  '/city/bhind',
#  '/city/bhiwadi',
#  '/city/bhiwani',
#  '/city/bhopal',
#  '/city/bhubaneswar',
#  '/city/bhuj',
#  '/city/bhusawal',
#  '/city/bidar',
#  '/city/biharsharif',
#  '/city/bijapur',
#  '/city/bijnor',
#  '/city/bikaner',
#  '/city/bilaspur',
#  '/city/bilaspur-hp',
#  '/city/bilimora',
#  '/city/biswanath-chariali',
#  '/city/bodhan-rural',
#  '/city/bodinayakanur',
#  '/city/boisar',
#  '/city/bokaro',
#  '/city/bolpur',
#  '/city/bongaigaon',
#  '/city/bongaon',
#  '/city/budaun',
#  '/city/budhwal',
#  '/city/bulandshahr',
#  '/city/buldana',
#  '/city/bundi',
#  '/city/burhanpur',
#  '/city/buxar',
#  '/city/central-goa',
#  '/city/chaibasa',
#  '/city/chakdaha',
#  '/city/chalakkudy',
#  '/city/chalisgaon',
#  '/city/chandausi',
#  '/city/chandigarh',
#  '/city/chandrapur',
#  '/city/changanassery',
#  '/city/charkhi-dadri_perm_closed_8june22',
#  '/city/chengannur',
#  '/city/chennai',
#  '/city/chhapra',
#  '/city/chhatarpur',
#  '/city/chhindwara',
#  '/city/chidambaram',
#  '/city/chikhli',
#  '/city/chikkaballapur',
#  '/city/chikmagalur',
#  '/city/chiplun',
#  '/city/chitradurga',
#  '/city/chittoor',
#  '/city/chittorgarh',
#  '/city/chopda',
#  '/city/churu',
#  '/city/coimbatore',
#  '/city/cooch-behar',
#  '/city/cuddalore',
#  '/city/cuttack',
#  '/city/dahanu',
#  '/city/dahod',
#  '/city/daltonganj',
#  '/city/daman',
#  '/city/darbhanga',
#  '/city/darjeeling',
#  '/city/daund',
#  '/city/dausa',
#  '/city/davanagere',
#  '/city/dehradun',
#  '/city/dehri',
#  '/city/delhi',
#  '/city/deoghar',
#  '/city/dewas',
#  '/city/dhanbad',
#  '/city/dhar',
#  '/city/dharamshala',
#  '/city/dharapuram',
#  '/city/dharmapuri',
#  '/city/dharwad',
#  '/city/dholpur',
#  '/city/dhoraji',
#  '/city/dhule',
#  '/city/dibrugarh',
#  '/city/digboi',
#  '/city/dimapur',
#  '/city/dindigul',
#  '/city/diu',
#  '/city/doddaballapura',
#  '/city/duliajan',
#  '/city/dumka',
#  '/city/dungarpur',
#  '/city/durgapur',
#  '/city/dwarka',
#  '/city/eluru',
#  '/city/erode',
#  '/city/etah',
#  '/city/etawah',
#  '/city/faizabad',
#  '/city/faridabad',
#  '/city/faridkot',
#  '/city/farrukhabad',
#  '/city/fatehabad',
#  '/city/fatehgarh-sahib',
#  '/city/fatehpur',
#  '/city/fazilka',
#  '/city/firozabad',
#  '/city/firozpur',
#  '/city/gadag-betigeri',
#  '/city/gadwal',
#  '/city/gandhidham',
#  '/city/gangapur-city',
#  '/city/gangarampur',
#  '/city/gangtok',
#  '/city/gauriganj',
#  '/city/gaya',
#  '/city/giridih',
#  '/city/godhra',
#  '/city/gokak',
#  '/city/golaghat',
#  '/city/gonda',
#  '/city/gondal',
#  '/city/gondia',
#  '/city/gopalganj',
#  '/city/gorakhpur',
#  '/city/gudivada',
#  '/city/guna',
#  '/city/guntakal',
#  '/city/guntur',
#  '/city/gurdaspur',
#  '/city/gurgaon',
#  '/city/guwahati',
#  '/city/gwalior',
#  '/city/habra',
#  '/city/hajipur',
#  '/city/haldia',
#  '/city/haldwani',
#  '/city/halol',
#  '/city/hamirpur',
#  '/city/hampi',
#  '/city/hansi',
#  '/city/hanumangarh',
#  '/city/hapur',
#  '/city/hardoi',
#  '/city/haridwar',
#  '/city/hassan',
#  '/city/hathras',
#  '/city/haveri',
#  '/city/himmatnagar',
#  '/city/hindaun',
#  '/city/hinganghat',
#  '/city/hisar',
#  '/city/hoshangabad',
#  '/city/hoshiarpur',
#  '/city/hospet',
#  '/city/hosur',
#  '/city/hubli',
#  '/city/hyderabad',
#  '/city/ichalkaranji',
#  '/city/idukki',
#  '/city/imphal',
#  '/city/indore',
#  '/city/irinjalakuda',
#  '/city/itanagar',
#  '/city/itarsi',
#  '/city/jabalpur',
#  '/city/jagdalpur',
#  '/city/jagraon',
#  '/city/jagtial',
#  '/city/jahanabad',
#  '/city/jaigaon',
#  '/city/jaipur',
#  '/city/jalandhar',
#  '/city/jalaun',
#  '/city/jalgaon',
#  '/city/jalpaiguri',
#  '/city/jammu',
#  '/city/jamnagar',
#  '/city/jamshedpur',
#  '/city/jaunpur',
#  '/city/jhalawar',
#  '/city/jhansi',
#  '/city/jhargram',
#  '/city/jhunjhunu',
#  '/city/jind',
#  '/city/jjajjar',
#  '/city/jodhpur',
#  '/city/jorhat',
#  '/city/junagadh',
#  '/city/kadapa',
#  '/city/kadayanallur',
#  '/city/kadi',
#  '/city/kadiri',
#  '/city/kaithal',
#  '/city/kakinada',
#  '/city/kalaburagi',
#  '/city/kalady',
#  '/city/kalna',
#  '/city/kamareddy',
#  '/city/kanchrapara',
#  '/city/kannauj',
#  '/city/kannur',
#  '/city/kanpur',
#  '/city/kanyakumari',
#  '/city/kapurthala',
#  '/city/karad',
#  '/city/karaikal',
#  '/city/karaikkudi',
#  '/city/karimnagar',
#  '/city/karnal',
#  '/city/karunagappaly',
#  '/city/karur',
#  '/city/karwar',
#  '/city/kasaragod',
#  '/city/kashipur',
#  '/city/katihar',
#  '/city/katni',
#  '/city/kavali',
#  '/city/kayamkulam',
#  '/city/kendrapada',
#  '/city/kendujhar',
#  '/city/khalilabad',
#  '/city/khamgaon',
#  '/city/khammam',
#  '/city/khandwa',
#  '/city/khanna',
#  '/city/kharagpur',
#  '/city/khopoli',
#  '/city/kishanganj',
#  '/city/kishangarh',
#  '/city/kochi',
#  '/city/kodaikanal',
#  '/city/kohima',
#  '/city/kokrajhar',
#  '/city/kolar',
#  '/city/kolhapur',
#  '/city/kolkata',
#  '/city/kollam',
#  '/city/kopargaon',
#  '/city/koppal',
#  '/city/korba',
#  '/city/kota',
#  '/city/kotdwar',
#  '/city/kothagudem',
#  '/city/kothamanagalam',
#  '/city/kottakkal',
#  '/city/kottarakkara',
#  '/city/kottayam',
#  '/city/kovilpatti',
#  '/city/kozhikode',
#  '/city/krishnagiri',
#  '/city/krishnanagar',
#  '/city/kullu',
#  '/city/kumarakom',
#  '/city/kumbakonam',
#  '/city/kumta',
#  '/city/kundapura',
#  '/city/kunnamkullam',
#  '/city/kurnool',
#  '/city/kurukshetra',
#  '/city/kushalnagar',
#  '/city/lakhimpur',
#  '/city/lalitpur',
#  '/city/latur',
#  '/city/lonavala',
#  '/city/lonavla',
#  '/city/lucknow',
#  '/city/ludhiana',
#  '/city/machilipatnam',
#  '/city/madanapalle',
#  '/city/madhubani',
#  '/city/madikeri',
#  '/city/madurai',
#  '/city/mahabaleshwar',
#  '/city/mahbubnagar',
#  '/city/mahoba',
#  '/city/malappuram',
#  '/city/malda',
#  '/city/malegaon',
#  '/city/malout',
#  '/city/manali',
#  '/city/mancherial',
#  '/city/mandi-dabwali',
#  '/city/mandi-gobindgarh',
#  '/city/mandi-hp',
#  '/city/mandsaur',
#  '/city/mandya',
#  '/city/mangaluru',
#  '/city/manipal',
#  '/city/manjeri',
#  '/city/mannargudi',
#  '/city/mansa',
#  '/city/markapur',
#  '/city/mathura',
#  '/city/maunath-bhanjan',
#  '/city/mayiladuthurai',
#  '/city/medinipur',
#  '/city/meerut',
#  '/city/mehsana',
#  '/city/mettupalayam',
#  '/city/miryalaguda',
#  '/city/mirzapur',
#  '/city/modinagar',
#  '/city/moga',
#  '/city/moodbidri',
#  '/city/moradabad',
#  '/city/morbi',
#  '/city/morena',
#  '/city/motihari',
#  '/city/mount-abu',
#  '/city/mughalsarai',
#  '/city/mukerian',
#  '/city/muktsar',
#  '/city/mumbai',
#  '/city/munger',
#  '/city/murshidabad',
#  '/city/mussoorie',
#  '/city/muvattupuzha',
#  '/city/muzaffarnagar',
#  '/city/muzaffarpur',
#  '/city/mysore',
#  '/city/nabadwip',
#  '/city/nadiad',
#  '/city/nagaon',
#  '/city/nagapattinam',
#  '/city/nagda',
#  '/city/nagercoil',
#  '/city/nagpur',
#  '/city/nagur',
#  '/city/naharlagun',
#  '/city/nainital',
#  '/city/nalbari',
#  '/city/nalgonda',
#  '/city/namakkal',
#  '/city/nanded',
#  '/city/nandurbar',
#  '/city/nandyal',
#  '/city/nangal',
#  '/city/naraingarh',
#  '/city/narasaraopet',
#  '/city/narnaul',
#  '/city/narsinghpur',
#  '/city/narsipatnam',
#  '/city/nashik',
#  '/city/navsari',
#  '/city/neemuch',
#  '/city/nellore',
#  '/city/neyveli',
#  '/city/nipani',
#  '/city/nirmal',
#  '/city/nizamabad',
#  '/city/noida',
#  '/city/noida-1',
#  '/city/north-goa',
#  '/city/ongole',
#  '/city/ooty',
#  '/city/orai',
#  '/city/osmanabad',
#  '/city/pala',
#  '/city/palakkad',
#  '/city/palakollu',
#  '/city/palampur',
#  '/city/palani',
#  '/city/palanpur',
#  '/city/palghar',
#  '/city/pali',
#  '/city/palwal',
#  '/city/panchgani',
#  '/city/panipat',
#  '/city/paramakudi',
#  '/city/parbhani',
#  '/city/pathankot',
#  '/city/patiala',
#  '/city/patna',
#  '/city/pattukkottai',
#  '/city/payyannur',
#  '/city/perambalur',
#  '/city/perinthalmanna',
#  '/city/phagwara',
#  '/city/phusro',
#  '/city/pilani',
#  '/city/pilibhit',
#  '/city/pinjore-city',
#  '/city/pondicherry',
#  '/city/porbandar',
#  '/city/port-blair',
#  '/city/pratapgarh',
#  '/city/proddatur',
#  '/city/pudukkottai',
#  '/city/pune',
#  '/city/puri',
#  '/city/purnea',
#  '/city/purulia',
#  '/city/pusad',
#  '/city/puttur',
#  '/city/puttur-karnataka',
#  '/city/rae-bareli',
#  '/city/raghunathpur',
#  '/city/raichur',
#  '/city/raiganj',
#  '/city/raigarh',
#  '/city/raipur',
#  '/city/rajahmundry',
#  '/city/rajapalayam',
#  '/city/rajgarh',
#  '/city/rajkot',
#  '/city/rajnandgaon',
#  '/city/rajsamand',
#  '/city/ramagundam',
#  '/city/ramanagara',
#  '/city/ramanathapuram',
#  '/city/ramgarh',
#  '/city/rampur',
#  '/city/ranaghat',
#  '/city/ranaghat-wb',
#  '/city/ranchi',
#  '/city/rangia',
#  '/city/rangpo',
#  '/city/ranibennur',
#  '/city/raniganj',
#  '/city/ratlam',
#  '/city/ratnagiri',
#  '/city/ravulapalem',
#  '/city/rayachoty',
#  '/city/rewa',
#  '/city/rewari',
#  '/city/rishikesh',
#  '/city/rohtak',
#  '/city/roorkee',
#  '/city/ropar',
#  '/city/rourkela',
#  '/city/rudrapur',
#  '/city/sagar',
#  '/city/saharsa',
#  '/city/salem',
#  '/city/samastipur',
#  '/city/sambalpur',
#  '/city/sangamner',
#  '/city/sangli',
#  '/city/sangrur',
#  '/city/santipur',
#  '/city/saputara',
#  '/city/sasaram',
#  '/city/satara',
#  '/city/satna',
#  '/city/sawai-madhopur',
#  '/city/sawantwadi',
#  '/city/sehore',
#  '/city/shahdol',
#  '/city/shahjahanpur',
#  '/city/shamli',
#  '/city/shikohabad',
#  '/city/shillong',
#  '/city/shimla',
#  '/city/shirdi-city',
#  '/city/shivamogga',
#  '/city/shivpuri',
#  '/city/shravasti',
#  '/city/shrirampur',
#  '/city/siddipet',
#  '/city/sikar',
#  '/city/silchar',
#  '/city/siliguri',
#  '/city/silvassa',
#  '/city/sindhanur',
#  '/city/singrauli',
#  '/city/sirkali',
#  '/city/sirsa',
#  '/city/sirsi',
#  '/city/sitamarhi',
#  '/city/sitapur',
#  '/city/sivakasi',
#  '/city/sivasagar',
#  '/city/siwan',
#  '/city/solan',
#  '/city/solapur',
#  '/city/sonipat',
#  '/city/south-goa',
#  '/city/sri-ganganagar',
#  '/city/srikakulam',
#  '/city/srivilliputhur',
#  '/city/sultanpur',
#  '/city/surat',
#  '/city/suratgarh',
#  '/city/surendranagar-dudhrej',
#  '/city/suri',
#  '/city/suryapet',
#  '/city/tadepalligudem',
#  '/city/tadpatri',
#  '/city/taliparambu',
#  '/city/tanuku',
#  '/city/tarn-taran-sahib',
#  '/city/tenkasi',
#  '/city/tezpur',
#  '/city/thalassery',
#  '/city/thanjavur',
#  '/city/theni',
#  '/city/thiruvalla',
#  '/city/thiruvallur',
#  '/city/thiruvananthapuram',
#  '/city/thiruvarur',
#  '/city/thodupuzha',
#  '/city/thoothukudi',
#  '/city/thrissur',
#  '/city/tindivanam',
#  '/city/tinsukia',
#  '/city/tiptur',
#  '/city/tirunelveli',
#  '/city/tirupati',
#  '/city/tirupur',
#  '/city/tiruttani',
#  '/city/tiruvannamalai',
#  '/city/tohana',
#  '/city/trichy',
#  '/city/tumakuru',
#  '/city/tuni',
#  '/city/udaipur',
#  '/city/udgir',
#  '/city/udhampur',
#  '/city/ujjain',
#  '/city/uluberia',
#  '/city/una',
#  '/city/unnao',
#  '/city/uran-islampur',
#  '/city/vadodara',
#  '/city/valsad',
#  '/city/vapi',
#  '/city/varanasi',
#  '/city/varkala',
#  '/city/vellore',
#  '/city/veraval',
#  '/city/vidisha',
#  '/city/vijayawada',
#  '/city/viluppuram',
#  '/city/virudhunagar',
#  '/city/visnagar',
#  '/city/vizag',
#  '/city/vizianagaram',
#  '/city/vyara',
#  '/city/waidhan',
#  '/city/warangal',
#  '/city/wardha',
#  '/city/washim',
#  '/city/wayanad',
#  '/city/yamuna-nagar',
#  '/city/yavatmal']

# %%
site = 'https://www.swiggy.com' 

new_urls = [site + url  for url in urls]

print (new_urls)
# Out:
# ['https://www.swiggy.com/city/abohar', 'https://www.swiggy.com/city/adilabad', 'https://www.swiggy.com/city/adityapur', 'https://www.swiggy.com/city/adoni', 'https://www.swiggy.com/city/agartala', 'https://www.swiggy.com/city/agra', 'https://www.swiggy.com/city/ahmedabad', 'https://www.swiggy.com/city/ahmednagar', 'https://www.swiggy.com/city/aizawl', 'https://www.swiggy.com/city/ajmer', 'https://www.swiggy.com/city/akola', 'https://www.swiggy.com/city/alappuzha', 'https://www.swiggy.com/city/aligarh', 'https://www.swiggy.com/city/alipurduar', 'https://www.swiggy.com/city/allahabad', 'https://www.swiggy.com/city/almora', 'https://www.swiggy.com/city/alwar', 'https://www.swiggy.com/city/amalapuram', 'https://www.swiggy.com/city/ambala', 'https://www.swiggy.com/city/ambejogai', 'https://www.swiggy.com/city/ambikapur', 'https://www.swiggy.com/city/ambur', 'https://www.swiggy.com/city/amravati', 'https://www.swiggy.com/city/amreli', 'https://www.swiggy.com/city/amritsar', 'https://www.swiggy.com/city/anand', 'https://www.swiggy.com/city/anantapur', 'https://www.swiggy.com/city/angul', 'https://www.swiggy.com/city/ankleshwar', 'https://www.swiggy.com/city/arakkonam', 'https://www.swiggy.com/city/arambagh', 'https://www.swiggy.com/city/arrah', 'https://www.swiggy.com/city/aruppukottai', 'https://www.swiggy.com/city/asansol', 'https://www.swiggy.com/city/aurangabad', 'https://www.swiggy.com/city/aurangabad_bihar', 'https://www.swiggy.com/city/azamgarh', 'https://www.swiggy.com/city/baddi', 'https://www.swiggy.com/city/bagalkot', 'https://www.swiggy.com/city/bagdogra', 'https://www.swiggy.com/city/bagula', 'https://www.swiggy.com/city/bahadurgarh', 'https://www.swiggy.com/city/bahraich', 'https://www.swiggy.com/city/balaghat', 'https://www.swiggy.com/city/balangir', 'https://www.swiggy.com/city/balasore', 'https://www.swiggy.com/city/ballari', 'https://www.swiggy.com/city/balrampur', 'https://www.swiggy.com/city/balurghat', 'https://www.swiggy.com/city/banda', 'https://www.swiggy.com/city/bangalore', 'https://www.swiggy.com/city/bankabihar', 'https://www.swiggy.com/city/bankura', 'https://www.swiggy.com/city/bantwal', 'https://www.swiggy.com/city/bapatlachirala', 'https://www.swiggy.com/city/baramati', 'https://www.swiggy.com/city/baran', 'https://www.swiggy.com/city/baraut', 'https://www.swiggy.com/city/bardhaman', 'https://www.swiggy.com/city/bardoli', 'https://www.swiggy.com/city/bareilly', 'https://www.swiggy.com/city/barh', 'https://www.swiggy.com/city/baripada', 'https://www.swiggy.com/city/barmer', 'https://www.swiggy.com/city/barnala', 'https://www.swiggy.com/city/barshi', 'https://www.swiggy.com/city/barwani', 'https://www.swiggy.com/city/basirhat', 'https://www.swiggy.com/city/basti', 'https://www.swiggy.com/city/batala', 'https://www.swiggy.com/city/bathinda', 'https://www.swiggy.com/city/beawar', 'https://www.swiggy.com/city/beed', 'https://www.swiggy.com/city/begusarai', 'https://www.swiggy.com/city/bela-pratapgarh', 'https://www.swiggy.com/city/belgaum', 'https://www.swiggy.com/city/berhampore', 'https://www.swiggy.com/city/berhampur', 'https://www.swiggy.com/city/bettiah', 'https://www.swiggy.com/city/betul', 'https://www.swiggy.com/city/bhadohi', 'https://www.swiggy.com/city/bhadrachalam', 'https://www.swiggy.com/city/bhadrak', 'https://www.swiggy.com/city/bhadravati', 'https://www.swiggy.com/city/bhagalpur', 'https://www.swiggy.com/city/bhandara', 'https://www.swiggy.com/city/bharabanki', 'https://www.swiggy.com/city/bharatpur', 'https://www.swiggy.com/city/bharuch', 'https://www.swiggy.com/city/bhatkal', 'https://www.swiggy.com/city/bhavnagar', 'https://www.swiggy.com/city/bhawanipatna', 'https://www.swiggy.com/city/bhilai', 'https://www.swiggy.com/city/bhilwara', 'https://www.swiggy.com/city/bhimavaram', 'https://www.swiggy.com/city/bhind', 'https://www.swiggy.com/city/bhiwadi', 'https://www.swiggy.com/city/bhiwani', 'https://www.swiggy.com/city/bhopal', 'https://www.swiggy.com/city/bhubaneswar', 'https://www.swiggy ...

# %%
len(new_urls)
# Out:
# 640
